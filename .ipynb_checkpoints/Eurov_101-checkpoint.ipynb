# %%
include("Mantzaris.jl")
include("demo.jl")
demo(1981,2008, 3)
# Out:
# Dict{Any, Any}("2way:1984-1987" => Any["Norway-Sweden"], "1way:1996-1999" => Any["Belgium-The Netherlands", "Croatia-Malta", "Croatia-Slovenia", "Cyprus-Greece", "Estonia-Sweden", "Finland-Estonia", "France-Portugal", "Germany-Turkey", "Greece-Cyprus", "Ireland-Sweden", "Malta-Croatia", "Norway-France", "Norway-Malta", "Norway-Sweden", "Poland-Estonia", "Slovakia-Malta", "Slovenia-Croatia", "Sweden-Estonia", "Sweden-Norway", "The Netherlands-Germany", "Turkey-Ireland", "Turkey-Malta", "United Kingdom-Estonia", "United Kingdom-Ireland"], "2way:1981-1984" => Any["Germany-Sweden"], "2way:1999-2002" => Any["Croatia-Slovenia", "Denmark-Estonia", "Denmark-Iceland", "Denmark-Sweden", "Estonia-Latvia", "Estonia-Sweden"], "1way:1984-1987" => Any["Austria-Ireland", "Belgium-Germany", "Belgium-Ireland", "Belgium-Norway", "Cyprus-Ireland", "Denmark-Germany", "Denmark-Sweden", "Finland-Belgium", "Finland-Ireland", "Finland-Sweden", "France-Denmark", "Germany-Norway", "Italy-Ireland", "Luxembourg-
# ...
